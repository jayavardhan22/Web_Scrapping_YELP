# %% [markdown]
# # **Student ID - 20046512**

# %%
# Environment_Setup

import requests
import json
import pandas as pd

#!pip install matplotlib seaborn
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Data Extraction using YELP URL**

# %%
# Data_Extraction


#URL of the Yelp search page is used for data extraction:
url='https://www.yelp.ie/search/snippet?find_desc=Restaurants&find_loc=Dublin&start=20&parent_request_id=79d4d4754a829085&request_origin=user'


# Headers to simulate a browser request
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

response = requests.get(url, headers=headers)


print(response.status_code)  # Check if the request was successful


data = response.json()  # Convert to JSON



data = json.dumps(data, indent=4)

print(data)
# Out:
# 200
# {
#     "adLoggingConfig": {
#         "adAckUrl": "/ad_acknowledgment",
#         "adAckCsrf": "d7781156ad337d9d1c3c1b1411b1706df8fa9ec9958dfa9036854bf73d7428a6",
#         "opportunityId": "f6aec1d15c3867ce"
#     },
#     "ajaxScrollablePhotosURI": "/biz_photos/scrollable_photos/CJZ9zMw4jS4muuCiWJncQw%2CVNKXa0f7IHkH7-C_WsXPVg%2C3riTLkulihvZ_cC4snJsyA%2CLjTHV5RRugnn2z97uJo-RQ%2C-VIve-QeHR9-cKr7QldqtA%2CMo1F-w1WgU256ORLbOMBIA%2CvyXI4BRA2zj6A7SQ-ycm0A%2CGPdeOr93UfNmHT7uSAKxGw%2CpiJzFA9r4xCV87bkoovM7Q%2CWIzjkFkFw-ppQS8E5tIs8w",
#     "autoEnabledAttributes": [],
#     "loggingConfig": {
#         "sitRepConfig": {
#             "isSitRepEnabled": true,
#             "enabledSitRepChannels": {
#                 "search_ux": true,
#                 "traffic_quality": true,
#                 "message_the_business": true,
#                 "vertical_search_reservation": true,
#                 "search_suggest_events": true,
#                 "ad_syndication": true,
#                 "ad_syndication_cookie_sync_errors": true,
#                 "ytp_session_events": true,
#                 "vertical_search_platform": true,
#                 "vertical_search_waitlist": true,
#                 "frontend_performance": true
#             },
#             "servletName": "www.search_ajax"
#         },
#         "sitRepParams": {
#             "uniqueRequestID": "f6aec1d15c3867ce",
#             "zipkinTraceID": "f6ad1dbdeba07997b5484cec819b208d",
#             "cfRayID": null,
#             "yuv_record": "86NbdLHlVnMiP1ok5t_ZACie66SrCBlQid7AF842psiJqDx00rtoGd-b_u7cIxgCt83PA-Kq2msPJZEIBQx1TAQNEQE_2OD3",
#             "serverStartTime": 1735606796870,
#             "datacenter": "us-west-2",
#             "site": "main",
#             "isLoggedIn": false,
#             "action": "search",
#             "servlet": "www.search_ajax",
#             "clientIP": "35.187.155.65",
#             "is_internal_ip": false,
#             "edgeStartTime": null,
#             "b3Sampled": "0",
#             "edgestageSubdomain": "_disabled",
#             "disableBeacon": false
#         }
#     },
#     "loggingData": {
#         "uniqueRequestId": "f6aec1d15c3867ce",
#         "gaConfig": {
#             "clientID": "7B3FEA3A3805FD7F",
#             "dimensions": {
#                 "global": {
#                     "account_level": [
#                         1,
#                         "anon"
#                     ],
#                     "content_country": [
#                         11,
#                         "IE"
#                     ],
#                     "distil": [
#                         12,
#                         null
#                     ],
#                     "distil_js_enabled": [
#                         13,
#                         null
#                     ],
#                     "exact_name_match": [
#                         14,
#                         "False"
#                     ],
#                     "full_url": [
#                         15,
#                         "/search/snippet?find_desc=Restaurants&find_loc=Dublin&start=20&parent_request_id=79d4d4754a829085&request_origin=user"
#                     ],
#                     "has_canonical": [
#                         16,
#                         "True"
#                     ],
#                     "integration": [
#                         17,
#                         ""
#                     ],
#                     "internal_ip": [
#                         18,
#                         "False"
#                     ],
#                     "is_indexable": [
#                         19,
#                         "True"
#                     ],
#                     "known_bot": [
#                         36,
#                         "none"
#                     ],
#                     "query_words_number": [
#                         25,
#                         "1"
#                     ],
#                     "referrer": [
#                         28,
#                         "none"
#                     ],
#                     "results_on_page": [
#                         29,
#                         "10"
#                     ],
#                     "search_accuracy": [
#                         30,
#                         "4"
#                     ],
#                     "search_city": [
#                         31,
#                         "Dublin"
#                     ],
#                     "search_location_lat_lng": [
#                         35,
#                         "53.3458,-6.26269"
#                     ],
#                     "top_level_categories": [
#                         7,
#                         "restaurants,nightlife"
#                     ]
#                 },
#                 "www": {
#                     "account_level": [
#                         1,
#                         "anon"
#                     ],
#                     "business_id": [
#                         141,
#                         ""
#                     ],
#                     "content_country": [
#                         15,
#                         "IE"
#                     ],
#                     "decrypted_yuv_id": [
#                         3,
#                         "7B3FEA3A3805FD7F"
#                     ],
#                     "distil": [
#                         53,
#                         null
#                     ],
#                     "distil_js_enabled": [
#                         138,
#                         null
#                     ],
#                     "exact_name_match": [
#                         50,
#                         "False"
#                     ],
#                     "full_url": [
#                         34,
#                         "/search/snippet?find_desc=Restaurants&find_loc=Dublin&start=20&parent_request_id=79d4d4754a829085&request_origin=user"
#                     ],
#                     "has_canonical": [
#                         36,
#                         "True"
#                     ],
#                     "integration": [
#                         14,
#                         ""
#                     ],
#                     "internal_ip": [
#                         27,
#                         "False"
#                     ],
#                     "is_biz_user": [
#                         129,
#                         "False"
#                     ],
#                     "is_indexable": [
#                         42,
#                         "True"
#                     ],
#                     "known_bot": [
#                         186,
#                         "none"
#                     ],
#                     "page_depth": [
#                         41,
#                         "2"
#                     ],
#                     "query_words_number": [
#                         52,
#                         "1"
#                     ],
#                     "referrer": [
#                         64,
#                         "none"
#                     ],
#                     "remote_ip": [
#                         4,
#                         "35.187.155.0"
#                     ],
#                     "results_on_page": [
#                         51,
#                         "10"
#                     ],
#                     "search_accuracy": [
#                         48,
#                         "4"
#                     ],
#                     "search_city": [
#                         49,
#                         "Dublin"
#                     ],
#                     "search_location_lat_lng": [
#                         109,
#                         "53.3458,-6.26269"
#                     ],
#                     "service": [
#                         107,
#                         "yelp-main"
#                     ],
#                     "top_level_categories": [
#                         11,
#                         "restaurants,nightlife"
#                     ],
#                     "viewport_tracking": [
#                         29,
#                         null
#                     ],
#                     "ad.web_carousel_bottom_of_biz": [
#                         78,
#                         "status_quo"
#                     ],
#                     "www_education_banner": [
#                         190,
#                         "enabled"
#                     ],
#                     "contributions.www.remove_review_draft_modules": [
#                         183,
#                         "status_quo"
#                     ],
#                     "contributions.www.war_attach_photos": [
#                         99,
#                         "enabled"
#                     ],
#                     "contributions.www.war_compose_recent_photos": [
#                         102,
#                         "enabled"
#                     ],
#                     "contributions.www.war_compose_redesign": [
#                         6,
#                         "enabled"
#                     ],
#                     "contributions.www.war_compose_signup": [
#                         148,
#                         "disabled"
#                     ],
#                     "eat24_free_delivery_banner": [
#                         45,
#                         "disabled"
#                     ],
#                     "lsat.www.dropdown_header": [
#                         54,
#                         "enabled"
#                     ],
#                     "messaging.www.composer_notifications_spam_and_hover_state": [
#                         177,
#                         "notifications_enabled"
#                     ],
#                     "mtb_weekly_growth_1": [
#                         85,
#                         "txn_growth.request_an_appointment_separated_search-enabled"
#                     ],
#                     "nav_show_message_count": [
#                         59,
#                         "show_message_count"
#                     ],
#                     "nowait_restaurant.www.no_wait_message": [
#                         106,
#                         "show_waitlist_instructions"
#                     ],
#                     "pagelet_mode_www_biz_details": [
#                         24,
#                         "allow_async"
#                     ],
#                     "payment.ux.www": [
#                         197,
#                         "enabled"
#                     ],
#                     "platform_pickup_filter": [
#                         20,
#                         "enabled"
#                     ],
#                     "readerx.web.biz_for_services": [
#                         116,
#                         "biz_status_quo"
#                     ],
#                     "readerx.web.popular_dishes": [
#                         198,
#                         "highlights_popular_dishes"
#                     ],
#                     "review_actions_dropdown": [
#                         2,
#                         "disabled"
#                     ],
#                     "styleguide_buttons": [
#                         13,
#                         "status_quo"
#                     ],
#                     "styleguide_typography": [
#                         159,
#                         "status_quo"
#                     ],
#                     "txn.www.checkout_page_changes": [
#                         135,
#                         "enabled"
#                     ],
#                     "www_biz_details_raq_sticky": [
#                         84,
#                         "enabled"
#                     ],
#                     "www_current_location_suggestion": [
#                         185,
#                         "enabled"
#                     ],
#                     "www_second_page_pitch": [
#                         111,
#                         "status_quo"
#                     ],
#                     "www_signup_redesign": [
#                         92,
#                         "status_quo"
#                     ],
#                     "ytp_delivery_landing": [
#                         125,
#                         "platform_pages"
#                     ],
#                     "ytp_eat24_yelp_style_to_iframe": [
#                         136,
#                         "status_quo"
#                     ],
#                     "ytp_order_confirmation_page": [
#                         143,
#                         "enabled"
#                     ],
#                     "www_search_snippets_in_sync_with_ads": [
#                         112,
#                         "status_quo_8"
#                     ],
#                     "yr_diner.www.direct_checkout_for_exact_match": [
#                         163,
#                         "disabled"
#                     ]
#                 }
#             },
#             "domain": "yelp.ie",
#             "enable_high_volume_events": false,
#             "ga_enabled": false,
#             "js_dimensions": {
#                 "global": {},
#                 "www": {
#                     "js_vertical_search_type": [
#                         39,
#                         null
#                     ],
#                     "platform_order_type": [
#                         127,
#                         null
#                     ]
#                 }
#             },
#             "metrics": {
#                 "global": {},
#                 "www": {
#                     "mtb-reply-rate-shown": [
#                         4,
#                         null
#                     ],
#                     "mtb-response-time-shown": [
#                         1,
#                         null
#                     ]
#                 }
#             },
#             "trackers": {
#                 "www": "UA-30501-24",
#                 "global": "UA-30501-1"
#             },
#             "user_id": null,
#             "customParameters": {}
#         }
#     },
#     "pageTitle": "TOP 10 BEST Restaurants in Dublin - Updated 2024 - Yelp",
#     "searchPageProps": {
#         "adBlockPlusChannelURIs": [
#             "/px.gif?ch=1&local_ads=1&rn=3&unique_request_id=f6aec1d15c3867ce&unique_visitor_id=7B3FEA3A3805FD7F",
#             "/px.gif?ch=2&local_ads=1&rn=3&unique_request_id=f6aec1d15c3867ce&unique_visitor_id=7B3FEA3A3805FD7F"
#         ],
#         "autoModalProps": null,
#         "filterPanelProps": {
#             "filterInfoMap": {
#                 "salad": {
#                     "name": "category",
#                     "text": "Salad",
#                     "tooltipText": null,
#                     "value": "salad",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "hotdogs": {
#                     "name": "category",
#                     "text": "Fast Food",
#                     "tooltipText": null,
#                     "value": "hotdogs",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "fishnchips": {
#                     "name": "category",
#                     "text": "Fish & Chips",
#                     "tooltipText": null,
#                     "value": "fishnchips",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "GoodForMeal.lunch": {
#                     "name": "suggested",
#                     "text": "Good for Lunch",
#                     "tooltipText": null,
#                     "value": "GoodForMeal.lunch",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "soulfood": {
#                     "name": "category",
#                     "text": "Soul Food",
#                     "tooltipText": null,
#                     "value": "soulfood",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "CoatCheck": {
#                     "name": "features",
#                     "text": "Coat Check",
#                     "tooltipText": null,
#                     "value": "CoatCheck",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "WiFi.free": {
#                     "name": "features",
#                     "text": "Free Wi-Fi",
#                     "tooltipText": null,
#                     "value": "WiFi.free",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "GoodForMeal.breakfast": {
#                     "name": "features",
#                     "text": "Good for Breakfast",
#                     "tooltipText": null,
#                     "value": "GoodForMeal.breakfast",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "pakistani": {
#                     "name": "category",
#                     "text": "Pakistani",
#                     "tooltipText": null,
#                     "value": "pakistani",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "halal": {
#                     "name": "category",
#                     "text": "Halal",
#                     "tooltipText": null,
#                     "value": "halal",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "latin": {
#                     "name": "category",
#                     "text": "Latin American",
#                     "tooltipText": null,
#                     "value": "latin",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "french": {
#                     "name": "category",
#                     "text": "French",
#                     "tooltipText": null,
#                     "value": "french",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "hawaiian": {
#                     "name": "category",
#                     "text": "Hawaiian",
#                     "tooltipText": null,
#                     "value": "hawaiian",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "RestaurantsDelivery": {
#                     "name": "suggested",
#                     "text": "Offers Delivery",
#                     "tooltipText": null,
#                     "value": "RestaurantsDelivery",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "breakfast_brunch": {
#                     "name": "category",
#                     "text": "Breakfast & Brunch",
#                     "tooltipText": null,
#                     "value": "breakfast_brunch",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "foodtrucks": {
#                     "name": "category",
#                     "text": "Food Trucks",
#                     "tooltipText": null,
#                     "value": "foodtrucks",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "pubs": {
#                     "name": "category",
#                     "text": "Pubs",
#                     "tooltipText": null,
#                     "value": "pubs",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "streetvendors": {
#                     "name": "category",
#                     "text": "Street Vendors",
#                     "tooltipText": null,
#                     "value": "streetvendors",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "GoodForMeal.brunch": {
#                     "name": "features",
#                     "text": "Good for Brunch",
#                     "tooltipText": null,
#                     "value": "GoodForMeal.brunch",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "irish_pubs": {
#                     "name": "category",
#                     "text": "Irish Pub",
#                     "tooltipText": null,
#                     "value": "irish_pubs",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "Music.dj": {
#                     "name": "features",
#                     "text": "Music: DJ",
#                     "tooltipText": null,
#                     "value": "Music.dj",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "BusinessParking.garage": {
#                     "name": "features",
#                     "text": "Garage Parking",
#                     "tooltipText": null,
#                     "value": "BusinessParking.garage",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "brasseries": {
#                     "name": "category",
#                     "text": "Brasseries",
#                     "tooltipText": null,
#                     "value": "brasseries",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "food_court": {
#                     "name": "category",
#                     "text": "Food Court",
#                     "tooltipText": null,
#                     "value": "food_court",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "persian": {
#                     "name": "category",
#                     "text": "Persian/Iranian",
#                     "tooltipText": null,
#                     "value": "persian",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "bbq": {
#                     "name": "category",
#                     "text": "Barbeque",
#                     "tooltipText": null,
#                     "value": "bbq",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "more_filters": {
#                     "name": "feature",
#                     "text": "more_filters",
#                     "tooltipText": null,
#                     "value": "more_filters",
#                     "isSelected": false,
#                     "isDisabled": true,
#                     "coachmark": null
#                 },
#                 "indpak": {
#                     "name": "category",
#                     "text": "Indian",
#                     "tooltipText": null,
#                     "value": "indpak",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "ramen": {
#                     "name": "category",
#                     "text": "Ramen",
#                     "tooltipText": null,
#                     "value": "ramen",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "sportsbars": {
#                     "name": "category",
#                     "text": "Sports Bars",
#                     "tooltipText": null,
#                     "value": "sportsbars",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "bistros": {
#                     "name": "category",
#                     "text": "Bistros",
#                     "tooltipText": null,
#                     "value": "bistros",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "BusinessParking.valet": {
#                     "name": "features",
#                     "text": "Valet Parking",
#                     "tooltipText": null,
#                     "value": "BusinessParking.valet",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "restaurants": {
#                     "name": "category",
#                     "text": "Restaurants",
#                     "tooltipText": null,
#                     "value": "restaurants",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "gluten_free": {
#                     "name": "category",
#                     "text": "Gluten-Free",
#                     "tooltipText": null,
#                     "value": "gluten_free",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "OutdoorSeating": {
#                     "name": "suggested",
#                     "text": "Outdoor Seating",
#                     "tooltipText": null,
#                     "value": "OutdoorSeating",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "southern": {
#                     "name": "category",
#                     "text": "Southern",
#                     "tooltipText": null,
#                     "value": "southern",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "asianfusion": {
#                     "name": "category",
#                     "text": "Asian Fusion",
#                     "tooltipText": null,
#                     "value": "asianfusion",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "BusinessParking.street": {
#                     "name": "features",
#                     "text": "Street Parking",
#                     "tooltipText": null,
#                     "value": "BusinessParking.street",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "Alcohol.full_bar": {
#                     "name": "features",
#                     "text": "Full Bar",
#                     "tooltipText": null,
#                     "value": "Alcohol.full_bar",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "irish": {
#                     "name": "category",
#                     "text": "Irish",
#                     "tooltipText": null,
#                     "value": "irish",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "himalayan": {
#                     "name": "category",
#                     "text": "Himalayan/Nepalese",
#                     "tooltipText": null,
#                     "value": "himalayan",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "arabian": {
#                     "name": "category",
#                     "text": "Arabic",
#                     "tooltipText": null,
#                     "value": "arabian",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "whiskeybars": {
#                     "name": "category",
#                     "text": "Whiskey Bars",
#                     "tooltipText": null,
#                     "value": "whiskeybars",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "tradamerican": {
#                     "name": "category",
#                     "text": "American",
#                     "tooltipText": null,
#                     "value": "tradamerican",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "Smoking.outdoor": {
#                     "name": "features",
#                     "text": "Smoking: Outdoor Area / Patio Only",
#                     "tooltipText": null,
#                     "value": "Smoking.outdoor",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "lounges": {
#                     "name": "category",
#                     "text": "Lounges",
#                     "tooltipText": null,
#                     "value": "lounges",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "vegetarian": {
#                     "name": "category",
#                     "text": "Vegetarian",
#                     "tooltipText": null,
#                     "value": "vegetarian",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "HasTV": {
#                     "name": "features",
#                     "text": "Has TV",
#                     "tooltipText": null,
#                     "value": "HasTV",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "lebanese": {
#                     "name": "category",
#                     "text": "Lebanese",
#                     "tooltipText": null,
#                     "value": "lebanese",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "dimsum": {
#                     "name": "category",
#                     "text": "Dim Sum",
#                     "tooltipText": null,
#                     "value": "dimsum",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "arts": {
#                     "name": "category",
#                     "text": "Arts & Entertainment",
#                     "tooltipText": null,
#                     "value": "arts",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "Smoking.yes": {
#                     "name": "features",
#                     "text": "Smoking: Yes",
#                     "tooltipText": null,
#                     "value": "Smoking.yes",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "seafood": {
#                     "name": "category",
#                     "text": "Seafood",
#                     "tooltipText": null,
#                     "value": "seafood",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "tapasmallplates": {
#                     "name": "category",
#                     "text": "Tapas/Small Plates",
#                     "tooltipText": null,
#                     "value": "tapasmallplates",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "szechuan": {
#                     "name": "category",
#                     "text": "Szechuan",
#                     "tooltipText": null,
#                     "value": "szechuan",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "panasian": {
#                     "name": "category",
#                     "text": "Pan Asian",
#                     "tooltipText": null,
#                     "value": "panasian",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "nightlife": {
#                     "name": "category",
#                     "text": "Nightlife",
#                     "tooltipText": null,
#                     "value": "nightlife",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "tex-mex": {
#                     "name": "category",
#                     "text": "Tex-Mex",
#                     "tooltipText": null,
#                     "value": "tex-mex",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "RestaurantsTableService": {
#                     "name": "features",
#                     "text": "Waiter Service",
#                     "tooltipText": null,
#                     "value": "RestaurantsTableService",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "malaysian": {
#                     "name": "category",
#                     "text": "Malaysian",
#                     "tooltipText": null,
#                     "value": "malaysian",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "vegan": {
#                     "name": "category",
#                     "text": "Vegan",
#                     "tooltipText": null,
#                     "value": "vegan",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "vietnamese": {
#                     "name": "category",
#                     "text": "Vietnamese",
#                     "tooltipText": null,
#                     "value": "vietnamese",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "eventservices": {
#                     "name": "category",
#                     "text": "Event Planning & Services",
#                     "tooltipText": null,
#                     "value": "eventservices",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "Music.karaoke": {
#                     "name": "features",
#                     "text": "Music: Karaoke",
#                     "tooltipText": null,
#                     "value": "Music.karaoke",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "food": {
#                     "name": "category",
#                     "text": "Food",
#                     "tooltipText": null,
#                     "value": "food",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "chickenshop": {
#                     "name": "category",
#                     "text": "Chicken Shop",
#                     "tooltipText": null,
#                     "value": "chickenshop",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "afghani": {
#                     "name": "category",
#                     "text": "Afghan",
#                     "tooltipText": null,
#                     "value": "afghani",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "mediterranean": {
#                     "name": "category",
#                     "text": "Mediterranean",
#                     "tooltipText": null,
#                     "value": "mediterranean",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "hotelstravel": {
#                     "name": "category",
#                     "text": "Hotels & Travel",
#                     "tooltipText": null,
#                     "value": "hotelstravel",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "foodstands": {
#                     "name": "category",
#                     "text": "Food Stands",
#                     "tooltipText": null,
#                     "value": "foodstands",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "Alcohol.beer_and_wine": {
#                     "name": "features",
#                     "text": "Beer & Wine Only",
#                     "tooltipText": null,
#                     "value": "Alcohol.beer_and_wine",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "musicvenues": {
#                     "name": "category",
#                     "text": "Music Venues",
#                     "tooltipText": null,
#                     "value": "musicvenues",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "kebab": {
#                     "name": "category",
#                     "text": "Kebab",
#                     "tooltipText": null,
#                     "value": "kebab",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "polish": {
#                     "name": "category",
#                     "text": "Polish",
#                     "tooltipText": null,
#                     "value": "polish",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "falafel": {
#                     "name": "category",
#                     "text": "Falafel",
#                     "tooltipText": null,
#                     "value": "falafel",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "fooddeliveryservices": {
#                     "name": "category",
#                     "text": "Food Delivery Services",
#                     "tooltipText": null,
#                     "value": "fooddeliveryservices",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "desserts": {
#                     "name": "category",
#                     "text": "Desserts",
#                     "tooltipText": null,
#                     "value": "desserts",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "gastropubs": {
#                     "name": "category",
#                     "text": "Gastropubs",
#                     "tooltipText": null,
#                     "value": "gastropubs",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "creperies": {
#                     "name": "category",
#                     "text": "Creperies",
#                     "tooltipText": null,
#                     "value": "creperies",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "tapas": {
#                     "name": "category",
#                     "text": "Tapas Bars",
#                     "tooltipText": null,
#                     "value": "tapas",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "gourmet": {
#                     "name": "category",
#                     "text": "Specialty Food",
#                     "tooltipText": null,
#                     "value": "gourmet",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "open_time": {
#                     "name": "features",
#                     "text": "Open At",
#                     "tooltipText": null,
#                     "value": "open_time",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null,
#                     "time": null
#                 },
#                 "british": {
#                     "name": "category",
#                     "text": "British",
#                     "tooltipText": null,
#                     "value": "british",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "sandwiches": {
#                     "name": "category",
#                     "text": "Sandwiches",
#                     "tooltipText": null,
#                     "value": "sandwiches",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "RestaurantsPriceRange2.1": {
#                     "name": "price",
#                     "text": "$",
#                     "tooltipText": null,
#                     "value": "RestaurantsPriceRange2.1",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "cocktailbars": {
#                     "name": "category",
#                     "text": "Cocktail Bars",
#                     "tooltipText": null,
#                     "value": "cocktailbars",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "mexican": {
#                     "name": "category",
#                     "text": "Mexican",
#                     "tooltipText": null,
#                     "value": "mexican",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "RestaurantsTakeOut": {
#                     "name": "suggested",
#                     "text": "Offers Takeout",
#                     "tooltipText": null,
#                     "value": "RestaurantsTakeOut",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "GoodForMeal.dessert": {
#                     "name": "features",
#                     "text": "Good for Dessert",
#                     "tooltipText": null,
#                     "value": "GoodForMeal.dessert",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "RestaurantsPriceRange2.2": {
#                     "name": "price",
#                     "text": "$$",
#                     "tooltipText": null,
#                     "value": "RestaurantsPriceRange2.2",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "RestaurantsPriceRange2.3": {
#                     "name": "price",
#                     "text": "$$$",
#                     "tooltipText": null,
#                     "value": "RestaurantsPriceRange2.3",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "RestaurantsPriceRange2.4": {
#                     "name": "price",
#                     "text": "$$$$",
#                     "tooltipText": null,
#                     "value": "RestaurantsPriceRange2.4",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "open_now": {
#                     "name": "suggested",
#                     "text": "Open Now",
#                     "tooltipText": null,
#                     "value": "open_now",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "chinese": {
#                     "name": "category",
#                     "text": "Chinese",
#                     "tooltipText": null,
#                     "value": "chinese",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "japanese": {
#                     "name": "category",
#                     "text": "Japanese",
#                     "tooltipText": null,
#                     "value": "japanese",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "GoodForKids": {
#                     "name": "features",
#                     "text": "Good for Kids",
#                     "tooltipText": null,
#                     "value": "GoodForKids",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "Smoking.no": {
#                     "name": "features",
#                     "text": "Smoking: No",
#                     "tooltipText": null,
#                     "value": "Smoking.no",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "sushi": {
#                     "name": "category",
#                     "text": "Sushi Bars",
#                     "tooltipText": null,
#                     "value": "sushi",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "diners": {
#                     "name": "category",
#                     "text": "Diners",
#                     "tooltipText": null,
#                     "value": "diners",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "beerbar": {
#                     "name": "category",
#                     "text": "Beer Bar",
#                     "tooltipText": null,
#                     "value": "beerbar",
#                     "isSelected": false,
#                     "isDisabled": false,
#                     "coachmark": null
#                 },
#                 "noodles": {
#                     "name": "category",
#                     "text": "Noodles",
#                     "tooltipText": null,
#                     "value": "noodles",
#                     "isSelected": false,
#                     "isDisabled": false,
# ...
#                 "keywords": [
#                     "menu"
#                 ],
#                 "uploadDate": "2018-04-10T01:21:21+00:00",
#                 "caption": null,
#                 "businessName": "Catch-22"
#             },
#             {
#                 "businessEncid": "GPdeOr93UfNmHT7uSAKxGw",
#                 "contentUrl": "https://s3-media0.fl.yelpcdn.com/bphoto/0I8QHDG69QRKk9adxC3sjw/348s.jpg",
#                 "thumbnailUrl": "https://s3-media0.fl.yelpcdn.com/bphoto/0I8QHDG69QRKk9adxC3sjw/180s.jpg",
#                 "aggregateRating": 4.1,
#                 "author": "Dan E.",
#                 "uploadedLocation": {
#                     "address": "5-7 Lord Edward Street",
#                     "city": "Christchurch",
#                     "state": "D",
#                     "zip": "8",
#                     "country": "IE"
#                 },
#                 "encodingFormat": "JPEG",
#                 "isFamilyFriendly": true,
#                 "isAttachedToReview": false,
#                 "keywords": [
#                     "steak",
#                     "food"
#                 ],
#                 "uploadDate": "2023-04-21T14:33:17+00:00",
#                 "caption": "8 oz Filet",
#                 "businessName": "Bull & Castle"
#             },
#             {
#                 "businessEncid": "piJzFA9r4xCV87bkoovM7Q",
#                 "contentUrl": "https://s3-media0.fl.yelpcdn.com/bphoto/y6DjqpTLRHJIFD9w0B6H8A/348s.jpg",
#                 "thumbnailUrl": "https://s3-media0.fl.yelpcdn.com/bphoto/y6DjqpTLRHJIFD9w0B6H8A/180s.jpg",
#                 "aggregateRating": 4.0212765,
#                 "author": "Victoria E.",
#                 "uploadedLocation": {
#                     "address": "12-13 South Great George's Street",
#                     "city": "Dublin",
#                     "state": "D",
#                     "zip": "2",
#                     "country": "IE"
#                 },
#                 "encodingFormat": "JPEG",
#                 "isFamilyFriendly": true,
#                 "isAttachedToReview": false,
#                 "keywords": [
#                     "curry",
#                     "food"
#                 ],
#                 "uploadDate": "2024-05-24T19:48:27+00:00",
#                 "caption": null,
#                 "businessName": "Yamamori"
#             },
#             {
#                 "businessEncid": "WIzjkFkFw-ppQS8E5tIs8w",
#                 "contentUrl": "https://s3-media0.fl.yelpcdn.com/bphoto/05pgSr_9xVpTxgzvJxBg0A/348s.jpg",
#                 "thumbnailUrl": "https://s3-media0.fl.yelpcdn.com/bphoto/05pgSr_9xVpTxgzvJxBg0A/180s.jpg",
#                 "aggregateRating": 4.3939395,
#                 "author": "Crystal R.",
#                 "uploadedLocation": {
#                     "address": "28 Parkgate Street",
#                     "city": "Dublin",
#                     "state": "D",
#                     "zip": "8",
#                     "country": "IE"
#                 },
#                 "encodingFormat": "JPEG",
#                 "isFamilyFriendly": true,
#                 "isAttachedToReview": false,
#                 "keywords": [
#                     "food"
#                 ],
#                 "uploadDate": "2024-08-18T14:55:48+00:00",
#                 "caption": "Prime rib",
#                 "businessName": "Ryans Of Parkgate Street"
#             }
#         ],
#         "businessListStructuredData": {
#             "@context": "https://schema.org",
#             "@type": "ItemList",
#             "itemListElement": [
#                 {
#                     "@type": "ListItem",
#                     "position": 1,
#                     "item": {
#                         "@context": "https://schema.org",
#                         "@type": "FoodEstablishment",
#                         "name": "La Cucina Restaurant",
#                         "description": "Discover 10 reviews of La Cucina Restaurant, a nearby business for Italian",
#                         "image": [
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/q3i4L12htI1EpcEHNCRPmQ/1000s.jpg",
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/q3i4L12htI1EpcEHNCRPmQ/300s.jpg",
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/q3i4L12htI1EpcEHNCRPmQ/258s.jpg"
#                         ],
#                         "aggregateRating": {
#                             "@type": "AggregateRating",
#                             "ratingValue": "4.2",
#                             "reviewCount": "10"
#                         },
#                         "url": "https://www.yelp.ie/biz/la-cucina-restaurant-dublin"
#                     }
#                 },
#                 {
#                     "@type": "ListItem",
#                     "position": 2,
#                     "item": {
#                         "@context": "https://schema.org",
#                         "@type": "FoodEstablishment",
#                         "name": "The Quays Irish Restaurant",
#                         "description": "Discover 235 reviews of The Quays Irish Restaurant, a nearby business for Irish",
#                         "priceRange": "\u20ac\u20ac",
#                         "image": [
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/KjiK1Ci8qpVpx-mG5lIo_A/1000s.jpg",
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/KjiK1Ci8qpVpx-mG5lIo_A/300s.jpg",
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/KjiK1Ci8qpVpx-mG5lIo_A/258s.jpg"
#                         ],
#                         "aggregateRating": {
#                             "@type": "AggregateRating",
#                             "ratingValue": "4.2",
#                             "reviewCount": "235"
#                         },
#                         "url": "https://www.yelp.ie/biz/the-quays-irish-restaurant-dublin-2"
#                     }
#                 },
#                 {
#                     "@type": "ListItem",
#                     "position": 3,
#                     "item": {
#                         "@context": "https://schema.org",
#                         "@type": "FoodEstablishment",
#                         "name": "Murphy's Bistro Cafe",
#                         "description": "Discover 35 reviews of Murphy's Bistro Cafe, a nearby business for Cafes",
#                         "image": [
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/ldkbJHfZ2JOiaHVNqEfMOA/1000s.jpg",
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/ldkbJHfZ2JOiaHVNqEfMOA/300s.jpg",
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/ldkbJHfZ2JOiaHVNqEfMOA/258s.jpg"
#                         ],
#                         "aggregateRating": {
#                             "@type": "AggregateRating",
#                             "ratingValue": "4.6",
#                             "reviewCount": "35"
#                         },
#                         "url": "https://www.yelp.ie/biz/murphys-bistro-cafe-dublin"
#                     }
#                 },
#                 {
#                     "@type": "ListItem",
#                     "position": 4,
#                     "item": {
#                         "@context": "https://schema.org",
#                         "@type": "FoodEstablishment",
#                         "name": "Boeuf",
#                         "description": "Discover 32 reviews of Boeuf, a nearby business for Steakhouses, French",
#                         "image": [
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/WWwkOgNCbpmpaEElJGJYsQ/1000s.jpg",
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/WWwkOgNCbpmpaEElJGJYsQ/300s.jpg",
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/WWwkOgNCbpmpaEElJGJYsQ/258s.jpg"
#                         ],
#                         "aggregateRating": {
#                             "@type": "AggregateRating",
#                             "ratingValue": "4.8",
#                             "reviewCount": "32"
#                         },
#                         "url": "https://www.yelp.ie/biz/boeuf-dublin"
#                     }
#                 },
#                 {
#                     "@type": "ListItem",
#                     "position": 5,
#                     "item": {
#                         "@context": "https://schema.org",
#                         "@type": "FoodEstablishment",
#                         "name": "Elephant & Castle",
#                         "description": "Discover 378 reviews of Elephant & Castle, a nearby business for American, Chicken Wings, Breakfast & Brunch",
#                         "priceRange": "\u20ac\u20ac",
#                         "image": [
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/1XGdQjeUPuaPaUZo2m7G5g/1000s.jpg",
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/1XGdQjeUPuaPaUZo2m7G5g/300s.jpg",
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/1XGdQjeUPuaPaUZo2m7G5g/258s.jpg"
#                         ],
#                         "aggregateRating": {
#                             "@type": "AggregateRating",
#                             "ratingValue": "4.0",
#                             "reviewCount": "378"
#                         },
#                         "url": "https://www.yelp.ie/biz/elephant-and-castle-dublin"
#                     }
#                 },
#                 {
#                     "@type": "ListItem",
#                     "position": 6,
#                     "item": {
#                         "@context": "https://schema.org",
#                         "@type": "FoodEstablishment",
#                         "name": "Camden Kitchen",
#                         "description": "Discover 63 reviews of Camden Kitchen, a nearby business for Modern European, French",
#                         "priceRange": "\u20ac\u20ac",
#                         "image": [
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/ePIoNI81Gw0OlYmo-ReGEg/1000s.jpg",
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/ePIoNI81Gw0OlYmo-ReGEg/300s.jpg",
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/ePIoNI81Gw0OlYmo-ReGEg/258s.jpg"
#                         ],
#                         "aggregateRating": {
#                             "@type": "AggregateRating",
#                             "ratingValue": "4.4",
#                             "reviewCount": "63"
#                         },
#                         "url": "https://www.yelp.ie/biz/camden-kitchen-dublin"
#                     }
#                 },
#                 {
#                     "@type": "ListItem",
#                     "position": 7,
#                     "item": {
#                         "@context": "https://schema.org",
#                         "@type": "FoodEstablishment",
#                         "name": "Catch-22",
#                         "description": "Discover 13 reviews of Catch-22, a nearby business for Seafood",
#                         "image": [
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/DnD5cU0gaw2s_UJHmRPnFg/1000s.jpg",
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/DnD5cU0gaw2s_UJHmRPnFg/300s.jpg",
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/DnD5cU0gaw2s_UJHmRPnFg/258s.jpg"
#                         ],
#                         "aggregateRating": {
#                             "@type": "AggregateRating",
#                             "ratingValue": "4.3",
#                             "reviewCount": "13"
#                         },
#                         "url": "https://www.yelp.ie/biz/catch-22-dublin-2"
#                     }
#                 },
#                 {
#                     "@type": "ListItem",
#                     "position": 8,
#                     "item": {
#                         "@context": "https://schema.org",
#                         "@type": "EntertainmentBusiness",
#                         "name": "Bull & Castle",
#                         "description": "Discover 290 reviews of Bull & Castle, a nearby business for Pubs, Sports Bars, Steakhouses",
#                         "priceRange": "\u20ac\u20ac\u20ac",
#                         "image": [
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/0I8QHDG69QRKk9adxC3sjw/1000s.jpg",
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/0I8QHDG69QRKk9adxC3sjw/300s.jpg",
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/0I8QHDG69QRKk9adxC3sjw/258s.jpg"
#                         ],
#                         "aggregateRating": {
#                             "@type": "AggregateRating",
#                             "ratingValue": "4.1",
#                             "reviewCount": "290"
#                         },
#                         "url": "https://www.yelp.ie/biz/bull-and-castle-christchurch"
#                     }
#                 },
#                 {
#                     "@type": "ListItem",
#                     "position": 9,
#                     "item": {
#                         "@context": "https://schema.org",
#                         "@type": "FoodEstablishment",
#                         "name": "Yamamori",
#                         "description": "Discover 94 reviews of Yamamori, a nearby business for Japanese, Pubs",
#                         "priceRange": "\u20ac\u20ac",
#                         "image": [
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/y6DjqpTLRHJIFD9w0B6H8A/1000s.jpg",
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/y6DjqpTLRHJIFD9w0B6H8A/300s.jpg",
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/y6DjqpTLRHJIFD9w0B6H8A/258s.jpg"
#                         ],
#                         "aggregateRating": {
#                             "@type": "AggregateRating",
#                             "ratingValue": "4.0",
#                             "reviewCount": "94"
#                         },
#                         "url": "https://www.yelp.ie/biz/yamamori-dublin-8"
#                     }
#                 },
#                 {
#                     "@type": "ListItem",
#                     "position": 10,
#                     "item": {
#                         "@context": "https://schema.org",
#                         "@type": "FoodEstablishment",
#                         "name": "Ryans Of Parkgate Street",
#                         "description": "Discover 66 reviews of Ryans Of Parkgate Street, a nearby business for Steakhouses",
#                         "priceRange": "\u20ac\u20ac",
#                         "image": [
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/05pgSr_9xVpTxgzvJxBg0A/1000s.jpg",
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/05pgSr_9xVpTxgzvJxBg0A/300s.jpg",
#                             "https://s3-media0.fl.yelpcdn.com/bphoto/05pgSr_9xVpTxgzvJxBg0A/258s.jpg"
#                         ],
#                         "aggregateRating": {
#                             "@type": "AggregateRating",
#                             "ratingValue": "4.4",
#                             "reviewCount": "66"
#                         },
#                         "url": "https://www.yelp.ie/biz/ryans-of-parkgate-street-dublin-2"
#                     }
#                 }
#             ]
#         },
#         "searchContext": {
#             "topVertical": "restaurants",
#             "searchCategory": "newamerican",
#             "isBotRequest": false,
#             "bizSiteUrl": "https://biz.yelp.ie",
#             "searchContextId": "f6aec1d15c3867ce"
#         }
#     },
#     "searchPageShellProps": {
#         "consumerHeaderProps": {
#             "bizSiteURL": null,
#             "initialHiddenLocationInputName": "find_loc",
#             "initialHiddenLocationInputVal": "Dublin",
#             "initialIsCurrentLocation": false,
#             "initialIsMapArea": false,
#             "initialLocationDisplayVal": "Dublin",
#             "initialSearchDisplayVal": "Restaurants",
#             "logoutCsrfToken": "c88b1c62f782cb84386d3d5a75870cc665ee2de8965510a33328324051442b43"
#         },
#         "footerProps": {
#             "attributionSource": "acxiom"
#         },
#         "backendDebugData": null
#     }
# }

# %%
# Data_Transformation & Processing

import pandas as pd

data = response.json()

# Loop through 'mainContentComponentsListProps' to extract meaningful data
main_content_list = data['searchPageProps']['mainContentComponentsListProps']

# Extract relevant information for each business, including reviewCount, neighborhoods, phone, alias, and other details
business_data = [
    {
        "name": item['searchResultBusiness']['name'],
        "ranking": item['searchResultBusiness'].get('ranking', 'N/A'),  # Default to 'N/A' if not found
        "business_url": item['searchResultBusiness'].get('businessUrl', 'N/A'),
        "review_count": item['searchResultBusiness'].get('reviewCount', 'N/A'),
        "neighborhoods": ", ".join(item['searchResultBusiness'].get('neighborhoods', [])),  # Join list of neighborhoods
        "phone": item['searchResultBusiness'].get('phone', 'N/A'),
        "alias": item['searchResultBusiness'].get('alias', 'N/A'),
        "rating": item['searchResultBusiness'].get('rating', 'N/A'),
        "categories": ", ".join([category['title'] for category in item['searchResultBusiness'].get('categories', [])]),  # Categories
        "website": item['searchResultBusiness'].get('website', {}).get('href', 'N/A') if item['searchResultBusiness'].get('website') else 'N/A',
        "open_hours": item['searchResultBusiness'].get('businessSectionUrls', {}).get('open_hours', 'N/A') if item['searchResultBusiness'].get('businessSectionUrls') else 'N/A',
        "reviews_url": item['searchResultBusiness'].get('businessSectionUrls', {}).get('reviews', 'N/A') if item['searchResultBusiness'].get('businessSectionUrls') else 'N/A',
        "photo_href": item['scrollablePhotos'].get('photoHref', 'N/A') if item.get('scrollablePhotos') else 'N/A',  # Check if scrollablePhotos exists
        "all_photos_href": item['scrollablePhotos'].get('allPhotosHref', 'N/A') if item.get('scrollablePhotos') else 'N/A'  # Check if scrollablePhotos exists
    }
    for item in main_content_list
    if 'searchResultBusiness' in item
]

# Convert the extracted data into a DataFrame (table)
df = pd.DataFrame(business_data)

#pd.set_option('display.max_colwidth', None)

print(df.to_string(index=False))
# Out:
#                       name  ranking                                             business_url  review_count      neighborhoods         phone                               alias  rating                                                  categories                              website                                                                  open_hours                                                      reviews_url                                               photo_href                    all_photos_href
#       La Cucina Restaurant       21         /biz/la-cucina-restaurant-dublin?osq=Restaurants            10   South Inner City (01) 677 1221         la-cucina-restaurant-dublin     4.2                                   Italian, Casual, Intimate    https://www.lacucinarestaurant.ie         /biz/la-cucina-restaurant-dublin?osq=Restaurants#location-and-hours         /biz/la-cucina-restaurant-dublin?osq=Restaurants#reviews         /biz/la-cucina-restaurant-dublin?osq=Restaurants /biz_photos/CJZ9zMw4jS4muuCiWJncQw
# The Quays Irish Restaurant       22 /biz/the-quays-irish-restaurant-dublin-2?osq=Restaurants           235         Temple Bar (01) 679 1923 the-quays-irish-restaurant-dublin-2     4.2                                     Irish, Casual, Touristy       http://www.quaysrestaurant.com /biz/the-quays-irish-restaurant-dublin-2?osq=Restaurants#location-and-hours /biz/the-quays-irish-restaurant-dublin-2?osq=Restaurants#reviews /biz/the-quays-irish-restaurant-dublin-2?osq=Restaurants /biz_photos/VNKXa0f7IHkH7-C_WsXPVg
#       Murphy’s Bistro Cafe       23          /biz/murphys-bistro-cafe-dublin?osq=Restaurants            35   North Inner City (01) 865 6772          murphys-bistro-cafe-dublin     4.6                                     Cafes, Casual, Touristy          http://www.murphysbistro.ie          /biz/murphys-bistro-cafe-dublin?osq=Restaurants#location-and-hours          /biz/murphys-bistro-cafe-dublin?osq=Restaurants#reviews          /biz/murphys-bistro-cafe-dublin?osq=Restaurants /biz_photos/3riTLkulihvZ_cC4snJsyA
#                      Boeuf       24                        /biz/boeuf-dublin?osq=Restaurants            32   South Inner City (01) 677 1546                        boeuf-dublin     4.8                       Steakhouses, French, Casual, Romantic                      http://boeuf.ie                        /biz/boeuf-dublin?osq=Restaurants#location-and-hours                        /biz/boeuf-dublin?osq=Restaurants#reviews                        /biz/boeuf-dublin?osq=Restaurants /biz_photos/LjTHV5RRugnn2z97uJo-RQ
#          Elephant & Castle       25          /biz/elephant-and-castle-dublin?osq=Restaurants           378         Temple Bar (01) 679 3121          elephant-and-castle-dublin     4.0 American, Chicken Wings, Breakfast & Brunch, Casual, Trendy     http://www.elephantandcastle.ie/          /biz/elephant-and-castle-dublin?osq=Restaurants#location-and-hours          /biz/elephant-and-castle-dublin?osq=Restaurants#reviews          /biz/elephant-and-castle-dublin?osq=Restaurants /biz_photos/-VIve-QeHR9-cKr7QldqtA
#             Camden Kitchen       26               /biz/camden-kitchen-dublin?osq=Restaurants            63           Harcourt (01) 476 0125               camden-kitchen-dublin     4.4                     Modern European, French, Casual, Classy          http://www.camdenkitchen.ie               /biz/camden-kitchen-dublin?osq=Restaurants#location-and-hours               /biz/camden-kitchen-dublin?osq=Restaurants#reviews               /biz/camden-kitchen-dublin?osq=Restaurants /biz_photos/Mo1F-w1WgU256ORLbOMBIA
#                   Catch-22       27                   /biz/catch-22-dublin-2?osq=Restaurants            13   South Inner City (01) 441 4425                   catch-22-dublin-2     4.3                                   Seafood, Intimate, Classy                   http://catch-22.ie                   /biz/catch-22-dublin-2?osq=Restaurants#location-and-hours                   /biz/catch-22-dublin-2?osq=Restaurants#reviews                   /biz/catch-22-dublin-2?osq=Restaurants /biz_photos/vyXI4BRA2zj6A7SQ-ycm0A
#              Bull & Castle       28        /biz/bull-and-castle-christchurch?osq=Restaurants           290 Clanbrassil Street (01) 475 1122        bull-and-castle-christchurch     4.1            Pubs, Sports Bars, Steakhouses, Casual, Intimate http://bull-and-castle.fxbuckley.ie/        /biz/bull-and-castle-christchurch?osq=Restaurants#location-and-hours        /biz/bull-and-castle-christchurch?osq=Restaurants#reviews        /biz/bull-and-castle-christchurch?osq=Restaurants /biz_photos/GPdeOr93UfNmHT7uSAKxGw
#                   Yamamori       29                   /biz/yamamori-dublin-8?osq=Restaurants            94   South Inner City (01) 645 8001                   yamamori-dublin-8     4.0                             Japanese, Pubs, Casual, Hipster https://yamamori.ie/izakaya-sake-bar                   /biz/yamamori-dublin-8?osq=Restaurants#location-and-hours                   /biz/yamamori-dublin-8?osq=Restaurants#reviews                   /biz/yamamori-dublin-8?osq=Restaurants /biz_photos/piJzFA9r4xCV87bkoovM7Q
#   Ryans Of Parkgate Street       30   /biz/ryans-of-parkgate-street-dublin-2?osq=Restaurants            66       Phoneix Park (01) 677 6097   ryans-of-parkgate-street-dublin-2     4.4                               Steakhouses, Casual, Intimate            http://ryans.fxbuckley.ie   /biz/ryans-of-parkgate-street-dublin-2?osq=Restaurants#location-and-hours   /biz/ryans-of-parkgate-street-dublin-2?osq=Restaurants#reviews   /biz/ryans-of-parkgate-street-dublin-2?osq=Restaurants /biz_photos/WIzjkFkFw-ppQS8E5tIs8w

# %%
#Convert the structured data into  DataFrame

df = pd.DataFrame(business_data)
df
# Out:
#                          name  ranking  \
# 0        La Cucina Restaurant       21
# 1  The Quays Irish Restaurant       22
# 2        Murphy’s Bistro Cafe       23
# 3                       Boeuf       24
# 4           Elephant & Castle       25
# 5              Camden Kitchen       26
# 6                    Catch-22       27
# 7               Bull & Castle       28
# 8                    Yamamori       29
# 9    Ryans Of Parkgate Street       30
#
#                                         business_url  review_count  \
# 0   /biz/la-cucina-restaurant-dublin?osq=Restaurants            10
# 1  /biz/the-quays-irish-restaurant-dublin-2?osq=R...           235
# 2    /biz/murphys-bistro-cafe-dublin?osq=Restaurants            35
# 3                  /biz/boeuf-dublin?osq=Restaurants            32
# 4    /biz/elephant-and-castle-dublin?osq=Restaurants           378
# 5         /biz/camden-kitchen-dublin?osq=Restaurants            63
# 6             /biz/catch-22-dublin-2?osq=Restaurants            13
# 7  /biz/bull-and-castle-christchurch?osq=Restaurants           290
# 8             /biz/yamamori-dublin-8?osq=Restaurants            94
# 9  /biz/ryans-of-parkgate-street-dublin-2?osq=Res...            66
#
#         neighborhoods          phone                                alias  \
# 0    South Inner City  (01) 677 1221          la-cucina-restaurant-dublin
# 1          Temple Bar  (01) 679 1923  the-quays-irish-restaurant-dublin-2
# 2    North Inner City  (01) 865 6772           murphys-bistro-cafe-dublin
# 3    South Inner City  (01) 677 1546                         boeuf-dublin
# 4          Temple Bar  (01) 679 3121           elephant-and-castle-dublin
# 5            Harcourt  (01) 476 0125                camden-kitchen-dublin
# 6    South Inner City  (01) 441 4425                    catch-22-dublin-2
# 7  Clanbrassil Street  (01) 475 1122         bull-and-castle-christchurch
# 8    South Inner City  (01) 645 8001                    yamamori-dublin-8
# 9        Phoneix Park  (01) 677 6097    ryans-of-parkgate-street-dublin-2
#
#    rating                                         categories  \
# 0     4.2                          Italian, Casual, Intimate
# 1     4.2                            Irish, Casual, Touristy
# 2     4.6                            Cafes, Casual, Touristy
# 3     4.8              Steakhouses, French, Casual, Romantic
# 4     4.0  American, Chicken Wings, Breakfast & Brunch, C...
# 5     4.4            Modern European, French, Casual, Classy
# 6     4.3                          Seafood, Intimate, Classy
# 7     4.1   Pubs, Sports Bars, Steakhouses, Casual, Intimate
# 8     4.0                    Japanese, Pubs, Casual, Hipster
# 9     4.4                      Steakhouses, Casual, Intimate
#
#                                 website  \
# 0     https://www.lacucinarestaurant.ie
# 1        http://www.quaysrestaurant.com
# 2           http://www.murphysbistro.ie
# 3                       http://boeuf.ie
# 4      http://www.elephantandcastle.ie/
# 5           http://www.camdenkitchen.ie
# 6                    http://catch-22.ie
# 7  http://bull-and-castle.fxbuckley.ie/
# 8  https://yamamori.ie/izakaya-sake-bar
# 9             http://ryans.fxbuckley.ie
#
#                                           open_hours  \
# 0  /biz/la-cucina-restaurant-dublin?osq=Restauran...
# 1  /biz/the-quays-irish-restaurant-dublin-2?osq=R...
# 2  /biz/murphys-bistro-cafe-dublin?osq=Restaurant...
# 3  /biz/boeuf-dublin?osq=Restaurants#location-and...
# 4  /biz/elephant-and-castle-dublin?osq=Restaurant...
# 5  /biz/camden-kitchen-dublin?osq=Restaurants#loc...
# 6  /biz/catch-22-dublin-2?osq=Restaurants#locatio...
# 7  /biz/bull-and-castle-christchurch?osq=Restaura...
# 8  /biz/yamamori-dublin-8?osq=Restaurants#locatio...
# 9  /biz/ryans-of-parkgate-street-dublin-2?osq=Res...
#
#                                          reviews_url  \
# 0  /biz/la-cucina-restaurant-dublin?osq=Restauran...
# 1  /biz/the-quays-irish-restaurant-dublin-2?osq=R...
# 2  /biz/murphys-bistro-cafe-dublin?osq=Restaurant...
# 3          /biz/boeuf-dublin?osq=Restaurants#reviews
# 4  /biz/elephant-and-castle-dublin?osq=Restaurant...
# 5  /biz/camden-kitchen-dublin?osq=Restaurants#rev...
# 6     /biz/catch-22-dublin-2?osq=Restaurants#reviews
# 7  /biz/bull-and-castle-christchurch?osq=Restaura...
# 8     /biz/yamamori-dublin-8?osq=Restaurants#reviews
# 9  /biz/ryans-of-parkgate-street-dublin-2?osq=Res...
#
#                                           photo_href  \
# 0   /biz/la-cucina-restaurant-dublin?osq=Restaurants
# 1  /biz/the-quays-irish-restaurant-dublin-2?osq=R...
# 2    /biz/murphys-bistro-cafe-dublin?osq=Restaurants
# 3                  /biz/boeuf-dublin?osq=Restaurants
# 4    /biz/elephant-and-castle-dublin?osq=Restaurants
# 5         /biz/camden-kitchen-dublin?osq=Restaurants
# 6             /biz/catch-22-dublin-2?osq=Restaurants
# 7  /biz/bull-and-castle-christchurch?osq=Restaurants
# 8             /biz/yamamori-dublin-8?osq=Restaurants
# 9  /biz/ryans-of-parkgate-street-dublin-2?osq=Res...
#
#                       all_photos_href
# 0  /biz_photos/CJZ9zMw4jS4muuCiWJncQw
# 1  /biz_photos/VNKXa0f7IHkH7-C_WsXPVg
# 2  /biz_photos/3riTLkulihvZ_cC4snJsyA
# 3  /biz_photos/LjTHV5RRugnn2z97uJo-RQ
# 4  /biz_photos/-VIve-QeHR9-cKr7QldqtA
# 5  /biz_photos/Mo1F-w1WgU256ORLbOMBIA
# 6  /biz_photos/vyXI4BRA2zj6A7SQ-ycm0A
# 7  /biz_photos/GPdeOr93UfNmHT7uSAKxGw
# 8  /biz_photos/piJzFA9r4xCV87bkoovM7Q
# 9  /biz_photos/WIzjkFkFw-ppQS8E5tIs8w

# %% [markdown]
# ## **FEATURE ENGINEERING**

# %%
#FEATURE_ENGINEERING

#Standardize Phone Numbers

import re

def standardize_phone_number(phone):
    match = re.search(r'\(01\)\s*(\d{3})\s*(\d{4})', phone)
    if match:
        return f"+353-{match.group(1)}-{match.group(2)}"
    return phone  # Return as-is if no match

df['phone'] = df['phone'].apply(standardize_phone_number)
df
# Out:
#                          name  ranking  \
# 0        La Cucina Restaurant       21
# 1  The Quays Irish Restaurant       22
# 2        Murphy’s Bistro Cafe       23
# 3                       Boeuf       24
# 4           Elephant & Castle       25
# 5              Camden Kitchen       26
# 6                    Catch-22       27
# 7               Bull & Castle       28
# 8                    Yamamori       29
# 9    Ryans Of Parkgate Street       30
#
#                                         business_url  review_count  \
# 0   /biz/la-cucina-restaurant-dublin?osq=Restaurants            10
# 1  /biz/the-quays-irish-restaurant-dublin-2?osq=R...           235
# 2    /biz/murphys-bistro-cafe-dublin?osq=Restaurants            35
# 3                  /biz/boeuf-dublin?osq=Restaurants            32
# 4    /biz/elephant-and-castle-dublin?osq=Restaurants           378
# 5         /biz/camden-kitchen-dublin?osq=Restaurants            63
# 6             /biz/catch-22-dublin-2?osq=Restaurants            13
# 7  /biz/bull-and-castle-christchurch?osq=Restaurants           290
# 8             /biz/yamamori-dublin-8?osq=Restaurants            94
# 9  /biz/ryans-of-parkgate-street-dublin-2?osq=Res...            66
#
#         neighborhoods          phone                                alias  \
# 0    South Inner City  +353-677-1221          la-cucina-restaurant-dublin
# 1          Temple Bar  +353-679-1923  the-quays-irish-restaurant-dublin-2
# 2    North Inner City  +353-865-6772           murphys-bistro-cafe-dublin
# 3    South Inner City  +353-677-1546                         boeuf-dublin
# 4          Temple Bar  +353-679-3121           elephant-and-castle-dublin
# 5            Harcourt  +353-476-0125                camden-kitchen-dublin
# 6    South Inner City  +353-441-4425                    catch-22-dublin-2
# 7  Clanbrassil Street  +353-475-1122         bull-and-castle-christchurch
# 8    South Inner City  +353-645-8001                    yamamori-dublin-8
# 9        Phoneix Park  +353-677-6097    ryans-of-parkgate-street-dublin-2
#
#    rating                                         categories  \
# 0     4.2                          Italian, Casual, Intimate
# 1     4.2                            Irish, Casual, Touristy
# 2     4.6                            Cafes, Casual, Touristy
# 3     4.8              Steakhouses, French, Casual, Romantic
# 4     4.0  American, Chicken Wings, Breakfast & Brunch, C...
# 5     4.4            Modern European, French, Casual, Classy
# 6     4.3                          Seafood, Intimate, Classy
# 7     4.1   Pubs, Sports Bars, Steakhouses, Casual, Intimate
# 8     4.0                    Japanese, Pubs, Casual, Hipster
# 9     4.4                      Steakhouses, Casual, Intimate
#
#                                 website  \
# 0     https://www.lacucinarestaurant.ie
# 1        http://www.quaysrestaurant.com
# 2           http://www.murphysbistro.ie
# 3                       http://boeuf.ie
# 4      http://www.elephantandcastle.ie/
# 5           http://www.camdenkitchen.ie
# 6                    http://catch-22.ie
# 7  http://bull-and-castle.fxbuckley.ie/
# 8  https://yamamori.ie/izakaya-sake-bar
# 9             http://ryans.fxbuckley.ie
#
#                                           open_hours  \
# 0  /biz/la-cucina-restaurant-dublin?osq=Restauran...
# 1  /biz/the-quays-irish-restaurant-dublin-2?osq=R...
# 2  /biz/murphys-bistro-cafe-dublin?osq=Restaurant...
# 3  /biz/boeuf-dublin?osq=Restaurants#location-and...
# 4  /biz/elephant-and-castle-dublin?osq=Restaurant...
# 5  /biz/camden-kitchen-dublin?osq=Restaurants#loc...
# 6  /biz/catch-22-dublin-2?osq=Restaurants#locatio...
# 7  /biz/bull-and-castle-christchurch?osq=Restaura...
# 8  /biz/yamamori-dublin-8?osq=Restaurants#locatio...
# 9  /biz/ryans-of-parkgate-street-dublin-2?osq=Res...
#
#                                          reviews_url  \
# 0  /biz/la-cucina-restaurant-dublin?osq=Restauran...
# 1  /biz/the-quays-irish-restaurant-dublin-2?osq=R...
# 2  /biz/murphys-bistro-cafe-dublin?osq=Restaurant...
# 3          /biz/boeuf-dublin?osq=Restaurants#reviews
# 4  /biz/elephant-and-castle-dublin?osq=Restaurant...
# 5  /biz/camden-kitchen-dublin?osq=Restaurants#rev...
# 6     /biz/catch-22-dublin-2?osq=Restaurants#reviews
# 7  /biz/bull-and-castle-christchurch?osq=Restaura...
# 8     /biz/yamamori-dublin-8?osq=Restaurants#reviews
# 9  /biz/ryans-of-parkgate-street-dublin-2?osq=Res...
#
#                                           photo_href  \
# 0   /biz/la-cucina-restaurant-dublin?osq=Restaurants
# 1  /biz/the-quays-irish-restaurant-dublin-2?osq=R...
# 2    /biz/murphys-bistro-cafe-dublin?osq=Restaurants
# 3                  /biz/boeuf-dublin?osq=Restaurants
# 4    /biz/elephant-and-castle-dublin?osq=Restaurants
# 5         /biz/camden-kitchen-dublin?osq=Restaurants
# 6             /biz/catch-22-dublin-2?osq=Restaurants
# 7  /biz/bull-and-castle-christchurch?osq=Restaurants
# 8             /biz/yamamori-dublin-8?osq=Restaurants
# 9  /biz/ryans-of-parkgate-street-dublin-2?osq=Res...
#
#                       all_photos_href
# 0  /biz_photos/CJZ9zMw4jS4muuCiWJncQw
# 1  /biz_photos/VNKXa0f7IHkH7-C_WsXPVg
# 2  /biz_photos/3riTLkulihvZ_cC4snJsyA
# 3  /biz_photos/LjTHV5RRugnn2z97uJo-RQ
# 4  /biz_photos/-VIve-QeHR9-cKr7QldqtA
# 5  /biz_photos/Mo1F-w1WgU256ORLbOMBIA
# 6  /biz_photos/vyXI4BRA2zj6A7SQ-ycm0A
# 7  /biz_photos/GPdeOr93UfNmHT7uSAKxGw
# 8  /biz_photos/piJzFA9r4xCV87bkoovM7Q
# 9  /biz_photos/WIzjkFkFw-ppQS8E5tIs8w

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             10 non-null     object
#  1   ranking          10 non-null     int64
#  2   business_url     10 non-null     object
#  3   review_count     10 non-null     int64
#  4   neighborhoods    10 non-null     object
#  5   phone            10 non-null     object
#  6   alias            10 non-null     object
#  7   rating           10 non-null     float64
#  8   categories       10 non-null     object
#  9   website          10 non-null     object
#  10  open_hours       10 non-null     object
#  11  reviews_url      10 non-null     object
#  12  photo_href       10 non-null     object
#  13  all_photos_href  10 non-null     object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.2+ KB
# None

# %%
# Drop the unnecessary columns - 'photo_href' and 'all_photos_href'
df = df.drop(['photo_href', 'all_photos_href'], axis=1)

# Verify the columns are removed
print(df.head())
# Out:
#                          name  ranking  \
# 0        La Cucina Restaurant       21
# 1  The Quays Irish Restaurant       22
# 2        Murphy’s Bistro Cafe       23
# 3                       Boeuf       24
# 4           Elephant & Castle       25
#
#                                         business_url  review_count  \
# 0   /biz/la-cucina-restaurant-dublin?osq=Restaurants            10
# 1  /biz/the-quays-irish-restaurant-dublin-2?osq=R...           235
# 2    /biz/murphys-bistro-cafe-dublin?osq=Restaurants            35
# 3                  /biz/boeuf-dublin?osq=Restaurants            32
# 4    /biz/elephant-and-castle-dublin?osq=Restaurants           378
#
#       neighborhoods          phone                                alias  \
# 0  South Inner City  +353-677-1221          la-cucina-restaurant-dublin
# 1        Temple Bar  +353-679-1923  the-quays-irish-restaurant-dublin-2
# 2  North Inner City  +353-865-6772           murphys-bistro-cafe-dublin
# 3  South Inner City  +353-677-1546                         boeuf-dublin
# 4        Temple Bar  +353-679-3121           elephant-and-castle-dublin
#
#    rating                                         categories  \
# 0     4.2                          Italian, Casual, Intimate
# 1     4.2                            Irish, Casual, Touristy
# 2     4.6                            Cafes, Casual, Touristy
# 3     4.8              Steakhouses, French, Casual, Romantic
# 4     4.0  American, Chicken Wings, Breakfast & Brunch, C...
#
#                              website  \
# 0  https://www.lacucinarestaurant.ie
# 1     http://www.quaysrestaurant.com
# 2        http://www.murphysbistro.ie
# 3                    http://boeuf.ie
# 4   http://www.elephantandcastle.ie/
#
#                                           open_hours  \
# 0  /biz/la-cucina-restaurant-dublin?osq=Restauran...
# 1  /biz/the-quays-irish-restaurant-dublin-2?osq=R...
# 2  /biz/murphys-bistro-cafe-dublin?osq=Restaurant...
# 3  /biz/boeuf-dublin?osq=Restaurants#location-and...
# 4  /biz/elephant-and-castle-dublin?osq=Restaurant...
#
#                                          reviews_url
# 0  /biz/la-cucina-restaurant-dublin?osq=Restauran...
# 1  /biz/the-quays-irish-restaurant-dublin-2?osq=R...
# 2  /biz/murphys-bistro-cafe-dublin?osq=Restaurant...
# 3          /biz/boeuf-dublin?osq=Restaurants#reviews
# 4  /biz/elephant-and-castle-dublin?osq=Restaurant...

# %%
#Verify data integrity

df.shape
# Out:
# (10, 12)

# %%
print(df.isnull().sum()) # Check for Missing Values
# Out:
# name             0
# ranking          0
# business_url     0
# review_count     0
# neighborhoods    0
# phone            0
# alias            0
# rating           0
# categories       0
# website          0
# open_hours       0
# reviews_url      0
# dtype: int64

# %%
df.tail()
# Out:
#                        name  ranking  \
# 5            Camden Kitchen       26
# 6                  Catch-22       27
# 7             Bull & Castle       28
# 8                  Yamamori       29
# 9  Ryans Of Parkgate Street       30
#
#                                         business_url  review_count  \
# 5         /biz/camden-kitchen-dublin?osq=Restaurants            63
# 6             /biz/catch-22-dublin-2?osq=Restaurants            13
# 7  /biz/bull-and-castle-christchurch?osq=Restaurants           290
# 8             /biz/yamamori-dublin-8?osq=Restaurants            94
# 9  /biz/ryans-of-parkgate-street-dublin-2?osq=Res...            66
#
#         neighborhoods          phone                              alias  \
# 5            Harcourt  +353-476-0125              camden-kitchen-dublin
# 6    South Inner City  +353-441-4425                  catch-22-dublin-2
# 7  Clanbrassil Street  +353-475-1122       bull-and-castle-christchurch
# 8    South Inner City  +353-645-8001                  yamamori-dublin-8
# 9        Phoneix Park  +353-677-6097  ryans-of-parkgate-street-dublin-2
#
#    rating                                        categories  \
# 5     4.4           Modern European, French, Casual, Classy
# 6     4.3                         Seafood, Intimate, Classy
# 7     4.1  Pubs, Sports Bars, Steakhouses, Casual, Intimate
# 8     4.0                   Japanese, Pubs, Casual, Hipster
# 9     4.4                     Steakhouses, Casual, Intimate
#
#                                 website  \
# 5           http://www.camdenkitchen.ie
# 6                    http://catch-22.ie
# 7  http://bull-and-castle.fxbuckley.ie/
# 8  https://yamamori.ie/izakaya-sake-bar
# 9             http://ryans.fxbuckley.ie
#
#                                           open_hours  \
# 5  /biz/camden-kitchen-dublin?osq=Restaurants#loc...
# 6  /biz/catch-22-dublin-2?osq=Restaurants#locatio...
# 7  /biz/bull-and-castle-christchurch?osq=Restaura...
# 8  /biz/yamamori-dublin-8?osq=Restaurants#locatio...
# 9  /biz/ryans-of-parkgate-street-dublin-2?osq=Res...
#
#                                          reviews_url
# 5  /biz/camden-kitchen-dublin?osq=Restaurants#rev...
# 6     /biz/catch-22-dublin-2?osq=Restaurants#reviews
# 7  /biz/bull-and-castle-christchurch?osq=Restaura...
# 8     /biz/yamamori-dublin-8?osq=Restaurants#reviews
# 9  /biz/ryans-of-parkgate-street-dublin-2?osq=Res...

# %%
df.describe()
# Out:
#         ranking  review_count     rating
# count  10.00000     10.000000  10.000000
# mean   25.50000    121.600000   4.300000
# std     3.02765    130.818959   0.258199
# min    21.00000     10.000000   4.000000
# 25%    23.25000     32.750000   4.125000
# 50%    25.50000     64.500000   4.250000
# 75%    27.75000    199.750000   4.400000
# max    30.00000    378.000000   4.800000

# %%
df["ranking"].describe()
# Out:
# count    10.00000
# mean     25.50000
# std       3.02765
# min      21.00000
# 25%      23.25000
# 50%      25.50000
# 75%      27.75000
# max      30.00000
# Name: ranking, dtype: float64

# %%
# Bar Plot of Restaurants by Review Count

top_restaurants = df.nlargest(10, 'review_count')

plt.figure(figsize=(12, 6))
sns.barplot(
    x='review_count',
    y='name',
    data=top_restaurants,
    palette='coolwarm',
   # hue='name'

)
plt.title('Top 10 Restaurants by Review Count', fontsize=16)
plt.xlabel('Review Count', fontsize=14)
plt.ylabel('Restaurant Name', fontsize=14)
plt.show()
# Out:
# <ipython-input-16-1fcafb1a6e2b>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# Bar Plot of Restaurants by Ratings

# Sort the data by rating
sorted_df = df.sort_values(by='rating', ascending=False)

# Set up the figure size
plt.figure(figsize=(12, 6))

# Create a basic bar chart
sns.barplot(x='rating',
            y='name',
            #hue='name',
            data=sorted_df,
            palette='Greens_r') # Reverse the palette with _r

# Add titles and labels
plt.title('Restaurant Ratings', fontsize=16)
plt.xlabel('Rating', fontsize=12)
plt.ylabel('Restaurant Name', fontsize=12)

# Display the chart
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-17-f4b25e95a225>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='rating',

# %%
# Save to File:


#from google.colab import drive
#drive.mount('/content/drive')

# %%
#pd.json_normalize(business_data).to_csv('/content/drive/MyDrive/Jp_testings/output.csv', index=False)

# %%
#pd.json_normalize(business_data).to_excel(r'/content/drive/MyDrive/Jp_testings/output.xlsx')

# %%
#pd.json_normalize(business_data).to_json(r'/content/drive/MyDrive/Jp_testings/output.json')

# %%
#pd.json_normalize(business_data).to_html(r'/content/drive/MyDrive/Jp_testings/output.html')

# %% [markdown]
# ## **SQLite Integration**

# %%
# Database Integration using SQLite database

# Import necessary libraries
import sqlite3

# Step 2: Create a connection to the SQLite database
conn = sqlite3.connect('Restaurants_data.db')

# Step 3: Write the DataFrame to the SQLite database
df.to_sql('Restaurants_stats', conn, if_exists='replace', index=False)

# Step 4: Query the database to verify data has been loaded correctly
print("Data in the 'Restaurants_stats' table:")

#Checking if the data is loaded
print(pd.read_sql('SELECT * FROM Restaurants_stats LIMIT 5;', conn))

# Step 5: Close the connection
conn.close()
# Out:
# Data in the 'Restaurants_stats' table:
#                          name  ranking  \
# 0        La Cucina Restaurant       21
# 1  The Quays Irish Restaurant       22
# 2        Murphy’s Bistro Cafe       23
# 3                       Boeuf       24
# 4           Elephant & Castle       25
#
#                                         business_url  review_count  \
# 0   /biz/la-cucina-restaurant-dublin?osq=Restaurants            10
# 1  /biz/the-quays-irish-restaurant-dublin-2?osq=R...           235
# 2    /biz/murphys-bistro-cafe-dublin?osq=Restaurants            35
# 3                  /biz/boeuf-dublin?osq=Restaurants            32
# 4    /biz/elephant-and-castle-dublin?osq=Restaurants           378
#
#       neighborhoods          phone                                alias  \
# 0  South Inner City  +353-677-1221          la-cucina-restaurant-dublin
# 1        Temple Bar  +353-679-1923  the-quays-irish-restaurant-dublin-2
# 2  North Inner City  +353-865-6772           murphys-bistro-cafe-dublin
# 3  South Inner City  +353-677-1546                         boeuf-dublin
# 4        Temple Bar  +353-679-3121           elephant-and-castle-dublin
#
#    rating                                         categories  \
# 0     4.2                          Italian, Casual, Intimate
# 1     4.2                            Irish, Casual, Touristy
# 2     4.6                            Cafes, Casual, Touristy
# 3     4.8              Steakhouses, French, Casual, Romantic
# 4     4.0  American, Chicken Wings, Breakfast & Brunch, C...
#
#                              website  \
# 0  https://www.lacucinarestaurant.ie
# 1     http://www.quaysrestaurant.com
# 2        http://www.murphysbistro.ie
# 3                    http://boeuf.ie
# 4   http://www.elephantandcastle.ie/
#
#                                           open_hours  \
# 0  /biz/la-cucina-restaurant-dublin?osq=Restauran...
# 1  /biz/the-quays-irish-restaurant-dublin-2?osq=R...
# 2  /biz/murphys-bistro-cafe-dublin?osq=Restaurant...
# 3  /biz/boeuf-dublin?osq=Restaurants#location-and...
# 4  /biz/elephant-and-castle-dublin?osq=Restaurant...
#
#                                          reviews_url
# 0  /biz/la-cucina-restaurant-dublin?osq=Restauran...
# 1  /biz/the-quays-irish-restaurant-dublin-2?osq=R...
# 2  /biz/murphys-bistro-cafe-dublin?osq=Restaurant...
# 3          /biz/boeuf-dublin?osq=Restaurants#reviews
# 4  /biz/elephant-and-castle-dublin?osq=Restaurant...

# %% [markdown]
# ## **UNIT TESTING**

# %%
import unittest  # Importing unittest module for testing
from unittest.mock import patch, Mock  # patch to mock requests, Mock to create mock objects
import requests  # Importing requests to handle HTTP requests
import pandas as pd  # Importing pandas for DataFrame manipulation


# Yelp Data Scraper
def fetch_yelp_data(url, headers):
    response = requests.get(url, headers=headers)  # Making the GET request
    response.raise_for_status()  # Raise error if status code indicates failure
    return response.json()  # Return JSON data from response


def transform_yelp_data(data):
    main_content_list = data['searchPageProps']['mainContentComponentsListProps']  # Extracting list of businesses from data
    business_data = [
        {
            "name": item['searchResultBusiness']['name'],  # Extracting business name
            "ranking": item['searchResultBusiness'].get('ranking', 'N/A'),  # Extracting ranking, default to 'N/A' if not found
            "phone": item['searchResultBusiness'].get('phone', 'N/A'),  # Extracting phone number, default to 'N/A' if not found
            "rating": item['searchResultBusiness'].get('rating', 'N/A'),  # Extracting rating, default to 'N/A' if not found
            "neighborhoods": ", ".join(item['searchResultBusiness'].get('neighborhoods', []))  # Joining neighborhoods into a string
        }
        for item in main_content_list  # Looping over the businesses list
        if 'searchResultBusiness' in item  # Filtering only valid business items
    ]
    return pd.DataFrame(business_data)  # Returning the data as a pandas DataFrame


# Unit Tests
class TestYelpScraper(unittest.TestCase):

    @patch('requests.get')  # Mocking requests.get to avoid actual API calls
    def test_fetch_yelp_data_success(self, mock_get):
        # Mocking a successful API response with status code 200
        mock_response = Mock()
        mock_response.status_code = 200
        mock_response.json.return_value = {
            'searchPageProps': {
                'mainContentComponentsListProps': [
                    {
                        'searchResultBusiness': {
                            'name': 'Restaurant A',
                            'ranking': '1',
                            'phone': '123456789',
                            'rating': 4.5,
                            'neighborhoods': ['Dublin Center']
                        }
                    }
                ]
            }
        }
        mock_get.return_value = mock_response  # Assigning the mocked response to the request

        url = 'https://www.yelp.ie/search/snippet?find_desc=Restaurants&find_loc=Dublin&start=20'  # Test URL
        headers = {'User-Agent': 'Mozilla/5.0'}  # Test headers
        result = fetch_yelp_data(url, headers)  # Calling the function to test

        self.assertEqual(mock_response.status_code, 200)  # Verifying status code is 200
        self.assertIn('searchPageProps', result)  # Verifying the 'searchPageProps' key is in the result

    @patch('requests.get')  # Mocking requests.get to simulate a failed request
    def test_fetch_yelp_data_failure(self, mock_get):
        # Simulating an API failure with status code 500
        mock_get.return_value.status_code = 500
        mock_get.return_value.raise_for_status.side_effect = requests.exceptions.HTTPError  # Raising an HTTPError

        url = 'https://www.yelp.ie/search/snippet?find_desc=Restaurants&find_loc=Dublin&start=20'  # Test URL
        headers = {'User-Agent': 'Mozilla/5.0'}  # Test headers

        with self.assertRaises(requests.exceptions.HTTPError):  # Expecting HTTPError to be raised
            fetch_yelp_data(url, headers)

    def test_transform_yelp_data(self):
        # Mocking input data for transformation
        mock_data = {
            'searchPageProps': {
                'mainContentComponentsListProps': [
                    {
                        'searchResultBusiness': {
                            'name': 'Restaurant A',
                            'ranking': '1',
                            'phone': '123456789',
                            'rating': 4.5,
                            'neighborhoods': ['Dublin Center']
                        }
                    }
                ]
            }
        }

        df = transform_yelp_data(mock_data)  # Transforming the mock data into a DataFrame

        self.assertEqual(len(df), 1)  # Verifying that one business is in the DataFrame
        self.assertIn('name', df.columns)  # Verifying 'name' column is present
        self.assertEqual(df.loc[0, 'name'], 'Restaurant A')  # Verifying the business name is 'Restaurant A'
        self.assertIn('ranking', df.columns)  # Verifying 'ranking' column is present
        self.assertIn('phone', df.columns)  # Verifying 'phone' column is present
        self.assertIn('rating', df.columns)  # Verifying 'rating' column is present
        self.assertIn('neighborhoods', df.columns)  # Verifying 'neighborhoods' column is present
        self.assertEqual(df.loc[0, 'rating'], 4.5)  # Verifying the rating is 4.5


# Run tests
if __name__ == '__main__':
    unittest.main(argv=[''], exit=False)  # Running the tests without exiting the interpreter
# Out:
# ...
# ----------------------------------------------------------------------
# Ran 3 tests in 0.010s
#
# OK
